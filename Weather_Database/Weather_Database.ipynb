# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %%
# Ipmort requests library
import requests
# Import API key
from config import api_key

import time
from datetime import datetime

# Starting URL for Weather Map API Call.
weather_api_key = api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f1425040ec0c7f39b4e453b1ab73e7a4

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + cities[i]
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

# Run an API request for each city
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Dat Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | portland
# Processing Record 5 of Set 1 | yatsushiro
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | charleston
# Processing Record 12 of Set 1 | meulaboh
# Processing Record 13 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | saldanha
# Processing Record 19 of Set 1 | jumla
# Processing Record 20 of Set 1 | namibe
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | margate
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | alice springs
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | pringsewu
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | astara
# Processing Record 39 of Set 1 | kaabong
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | flagstaff
# Processing Record 43 of Set 1 | uzhur-4
# City not found. Skipping...
# Processing Record 44 of Set 1 | karratha
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | mukhen
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | vardo
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | zarate
# Processing Record 3 of Set 2 | bonavista
# Processing Record 4 of Set 2 | pochutla
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | bandarbeyla
# Processing Record 7 of Set 2 | grindavik
# Processing Record 8 of Set 2 | bilibino
# Processing Record 9 of Set 2 | nuuk
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | mana
# Processing Record 12 of Set 2 | mombasa
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | aleksandrov gay
# Processing Record 15 of Set 2 | kristiansund
# Processing Record 16 of Set 2 | romilly-sur-seine
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | kamina
# Processing Record 19 of Set 2 | los llanos de aridane
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | goure
# Processing Record 25 of Set 2 | bud
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | dhidhdhoo
# Processing Record 30 of Set 2 | pitimbu
# Processing Record 31 of Set 2 | tilichiki
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | ipira
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | diapaga
# Processing Record 37 of Set 2 | luanda
# Processing Record 38 of Set 2 | polignano a mare
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | barahona
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | bighapur
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | evensk
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | liancheng
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | dalbandin
# Processing Record 50 of Set 2 | jardim
# Processing Record 1 of Set 3 | batemans bay
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | sioux lookout
# Processing Record 6 of Set 3 | ahuimanu
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | vaitape
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | pitea
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | coihueco
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | wattegama
# Processing Record 15 of Set 3 | gornopravdinsk
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | krabi
# Processing Record 18 of Set 3 | mahon
# Processing Record 19 of Set 3 | husavik
# Processing Record 20 of Set 3 | sao jose da coroa grande
# Processing Record 21 of Set 3 | broome
# Processing Record 22 of Set 3 | le vauclin
# Processing Record 23 of Set 3 | saint-michel-des-saints
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | bilopillya
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | hualmay
# Processing Record 28 of Set 3 | rumboci
# Processing Record 29 of Set 3 | turukhansk
# Processing Record 30 of Set 3 | tuktoyaktuk
# Processing Record 31 of Set 3 | palmer
# Processing Record 32 of Set 3 | hovd
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | udachnyy
# Processing Record 36 of Set 3 | lagoa
# Processing Record 37 of Set 3 | tanabe
# Processing Record 38 of Set 3 | asyut
# Processing Record 39 of Set 3 | novosheshminsk
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 3 | cacequi
# Processing Record 42 of Set 3 | faya
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | kathmandu
# Processing Record 45 of Set 3 | nelson bay
# Processing Record 46 of Set 3 | byron bay
# Processing Record 47 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 3 | ola
# Processing Record 49 of Set 3 | markova
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | hofn
# Processing Record 3 of Set 4 | erenhot
# Processing Record 4 of Set 4 | wanning
# Processing Record 5 of Set 4 | port augusta
# Processing Record 6 of Set 4 | harnosand
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | tambacounda
# Processing Record 9 of Set 4 | gat
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | suleya
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | tommot
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | goulburn
# Processing Record 18 of Set 4 | puerto cabezas
# Processing Record 19 of Set 4 | biak
# Processing Record 20 of Set 4 | tatawin
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | ishigaki
# Processing Record 23 of Set 4 | tagusao
# Processing Record 24 of Set 4 | butaritari
# Processing Record 25 of Set 4 | guane
# Processing Record 26 of Set 4 | mountain home
# Processing Record 27 of Set 4 | shieli
# Processing Record 28 of Set 4 | xiangxiang
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | maceio
# Processing Record 31 of Set 4 | boende
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | fez
# Processing Record 34 of Set 4 | itoman
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | teahupoo
# Processing Record 37 of Set 4 | viksoyri
# City not found. Skipping...
# Processing Record 38 of Set 4 | padang
# Processing Record 39 of Set 4 | pangnirtung
# Processing Record 40 of Set 4 | challapata
# Processing Record 41 of Set 4 | wanaka
# Processing Record 42 of Set 4 | puerto madryn
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | burnie
# Processing Record 45 of Set 4 | sola
# Processing Record 46 of Set 4 | kommunisticheskiy
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | fort nelson
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | daru
# Processing Record 1 of Set 5 | marsa matruh
# Processing Record 2 of Set 5 | riyadh
# Processing Record 3 of Set 5 | bichura
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | sitka
# Processing Record 6 of Set 5 | borovskoy
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | pelym
# Processing Record 9 of Set 5 | telemaco borba
# Processing Record 10 of Set 5 | karaton
# Processing Record 11 of Set 5 | nevers
# Processing Record 12 of Set 5 | moose factory
# Processing Record 13 of Set 5 | amahai
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | muros
# Processing Record 16 of Set 5 | egvekinot
# Processing Record 17 of Set 5 | aktau
# Processing Record 18 of Set 5 | aksu
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | airai
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | shebalino
# Processing Record 23 of Set 5 | kangaatsiaq
# Processing Record 24 of Set 5 | hun
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | alice town
# Processing Record 27 of Set 5 | te anau
# Processing Record 28 of Set 5 | general roca
# Processing Record 29 of Set 5 | takoradi
# Processing Record 30 of Set 5 | skreia
# Processing Record 31 of Set 5 | ginda
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | aban
# Processing Record 35 of Set 5 | gazanjyk
# Processing Record 36 of Set 5 | carndonagh
# Processing Record 37 of Set 5 | bathsheba
# Processing Record 38 of Set 5 | raudeberg
# Processing Record 39 of Set 5 | quatre cocos
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | ondjiva
# Processing Record 42 of Set 5 | comacchio
# Processing Record 43 of Set 5 | northam
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | zverinogolovskoye
# Processing Record 46 of Set 5 | praia
# Processing Record 47 of Set 5 | firminy
# Processing Record 48 of Set 5 | port said
# Processing Record 49 of Set 5 | kasulu
# Processing Record 50 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 6 | wellington
# Processing Record 3 of Set 6 | jones
# Processing Record 4 of Set 6 | kisangani
# Processing Record 5 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 6 | thunder bay
# Processing Record 7 of Set 6 | arraial do cabo
# Processing Record 8 of Set 6 | yeniseysk
# Processing Record 9 of Set 6 | chon daen
# Processing Record 10 of Set 6 | veraval
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | pisco
# Processing Record 13 of Set 6 | matagami
# Processing Record 14 of Set 6 | provideniya
# Processing Record 15 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 6 | amarillo
# Processing Record 17 of Set 6 | kouroussa
# Processing Record 18 of Set 6 | vostok
# Processing Record 19 of Set 6 | avarua
# Processing Record 20 of Set 6 | haines junction
# Processing Record 21 of Set 6 | feijo
# Processing Record 22 of Set 6 | saint george
# Processing Record 23 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 6 | norrtalje
# Processing Record 25 of Set 6 | boddam
# Processing Record 26 of Set 6 | alugan
# Processing Record 27 of Set 6 | ancud
# Processing Record 28 of Set 6 | winona
# Processing Record 29 of Set 6 | fairbanks
# Processing Record 30 of Set 6 | shenjiamen
# Processing Record 31 of Set 6 | deputatskiy
# Processing Record 32 of Set 6 | presidencia roque saenz pena
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | sao benedito do rio preto
# Processing Record 36 of Set 6 | cidreira
# Processing Record 37 of Set 6 | grand-santi
# Processing Record 38 of Set 6 | dikson
# Processing Record 39 of Set 6 | urengoy
# Processing Record 40 of Set 6 | yamethin
# Processing Record 41 of Set 6 | pocatello
# Processing Record 42 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 6 | azar shahr
# City not found. Skipping...
# Processing Record 44 of Set 6 | mercedes
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | waingapu
# Processing Record 47 of Set 6 | kamloops
# Processing Record 48 of Set 6 | naze
# Processing Record 49 of Set 6 | lusambo
# Processing Record 50 of Set 6 | katsuura
# Processing Record 1 of Set 7 | ca mau
# Processing Record 2 of Set 7 | tiznit
# Processing Record 3 of Set 7 | umm kaddadah
# Processing Record 4 of Set 7 | tromso
# Processing Record 5 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | vao
# Processing Record 7 of Set 7 | gunnedah
# Processing Record 8 of Set 7 | sibolga
# Processing Record 9 of Set 7 | hay river
# Processing Record 10 of Set 7 | lavrentiya
# Processing Record 11 of Set 7 | vila
# Processing Record 12 of Set 7 | emerald
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | znamenskoye
# Processing Record 15 of Set 7 | phan thiet
# Processing Record 16 of Set 7 | yarmouth
# Processing Record 17 of Set 7 | killybegs
# Processing Record 18 of Set 7 | balikpapan
# Processing Record 19 of Set 7 | buinsk
# Processing Record 20 of Set 7 | cap malheureux
# Processing Record 21 of Set 7 | khorramshahr
# Processing Record 22 of Set 7 | mount darwin
# Processing Record 23 of Set 7 | banikoara
# Processing Record 24 of Set 7 | mao
# Processing Record 25 of Set 7 | komsomolskiy
# Processing Record 26 of Set 7 | pathalgaon
# Processing Record 27 of Set 7 | altay
# Processing Record 28 of Set 7 | beruwala
# Processing Record 29 of Set 7 | kidal
# Processing Record 30 of Set 7 | chelno-vershiny
# Processing Record 31 of Set 7 | brigantine
# Processing Record 32 of Set 7 | djambala
# Processing Record 33 of Set 7 | benghazi
# Processing Record 34 of Set 7 | sipe sipe
# Processing Record 35 of Set 7 | kununurra
# Processing Record 36 of Set 7 | ballina
# Processing Record 37 of Set 7 | taiyuan
# Processing Record 38 of Set 7 | lixourion
# Processing Record 39 of Set 7 | kempsey
# Processing Record 40 of Set 7 | chincha alta
# Processing Record 41 of Set 7 | price
# Processing Record 42 of Set 7 | roma
# Processing Record 43 of Set 7 | oksbol
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | olot
# Processing Record 46 of Set 7 | port-gentil
# Processing Record 47 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 7 | marabba
# Processing Record 49 of Set 7 | uncia
# Processing Record 50 of Set 7 | vanimo
# Processing Record 1 of Set 8 | abu samrah
# Processing Record 2 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 8 | rio grande
# Processing Record 4 of Set 8 | ericeira
# Processing Record 5 of Set 8 | krasnoselkup
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | san andres
# Processing Record 8 of Set 8 | dwarka
# Processing Record 9 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 8 | sorland
# Processing Record 11 of Set 8 | changtu
# Processing Record 12 of Set 8 | oshogbo
# Processing Record 13 of Set 8 | tabou
# Processing Record 14 of Set 8 | kefamenanu
# Processing Record 15 of Set 8 | nhulunbuy
# Processing Record 16 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 8 | lensk
# Processing Record 18 of Set 8 | edwardsville
# Processing Record 19 of Set 8 | tomigusuku
# Processing Record 20 of Set 8 | grosse ile
# Processing Record 21 of Set 8 | esmeraldas
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | vestmannaeyjar
# Processing Record 24 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 8 | enid
# Processing Record 27 of Set 8 | miraflores
# Processing Record 28 of Set 8 | lublin
# Processing Record 29 of Set 8 | walajapet
# Processing Record 30 of Set 8 | huron
# Processing Record 31 of Set 8 | shirochanka
# Processing Record 32 of Set 8 | rock springs
# Processing Record 33 of Set 8 | santa rosa
# Processing Record 34 of Set 8 | xai-xai
# Processing Record 35 of Set 8 | zhicheng
# Processing Record 36 of Set 8 | uppsala
# Processing Record 37 of Set 8 | dehloran
# Processing Record 38 of Set 8 | sabha
# Processing Record 39 of Set 8 | onega
# Processing Record 40 of Set 8 | lasa
# Processing Record 41 of Set 8 | codajas
# Processing Record 42 of Set 8 | okhotsk
# Processing Record 43 of Set 8 | aguimes
# Processing Record 44 of Set 8 | goderich
# Processing Record 45 of Set 8 | pokhara
# Processing Record 46 of Set 8 | novopskov
# Processing Record 47 of Set 8 | osmena
# Processing Record 48 of Set 8 | praia da vitoria
# Processing Record 49 of Set 8 | zhangjiakou
# Processing Record 50 of Set 8 | maragogi
# Processing Record 1 of Set 9 | alzamay
# Processing Record 2 of Set 9 | oneonta
# Processing Record 3 of Set 9 | nome
# Processing Record 4 of Set 9 | yerraguntla
# Processing Record 5 of Set 9 | konibodom
# Processing Record 6 of Set 9 | bandundu
# Processing Record 7 of Set 9 | farafangana
# Processing Record 8 of Set 9 | qaqortoq
# Processing Record 9 of Set 9 | sundumbili
# Processing Record 10 of Set 9 | karpogory
# Processing Record 11 of Set 9 | arcata
# Processing Record 12 of Set 9 | griffith
# Processing Record 13 of Set 9 | tolstoy-yurt
# Processing Record 14 of Set 9 | norman wells
# Processing Record 15 of Set 9 | tuatapere
# Processing Record 16 of Set 9 | obigarm
# Processing Record 17 of Set 9 | liberal
# Processing Record 18 of Set 9 | eyl
# Processing Record 19 of Set 9 | marawi
# Processing Record 20 of Set 9 | souillac
# Processing Record 21 of Set 9 | coquimbo
# Processing Record 22 of Set 9 | cherlak
# Processing Record 23 of Set 9 | prince rupert
# Processing Record 24 of Set 9 | isla vista
# Processing Record 25 of Set 9 | asfi
# Processing Record 26 of Set 9 | plettenberg bay
# Processing Record 27 of Set 9 | aripuana
# Processing Record 28 of Set 9 | alofi
# Processing Record 29 of Set 9 | kargasok
# Processing Record 30 of Set 9 | tongchuan
# Processing Record 31 of Set 9 | faanui
# Processing Record 32 of Set 9 | denpasar
# Processing Record 33 of Set 9 | launceston
# Processing Record 34 of Set 9 | batagay-alyta
# Processing Record 35 of Set 9 | duldurga
# Processing Record 36 of Set 9 | nautla
# Processing Record 37 of Set 9 | zeya
# Processing Record 38 of Set 9 | dudinka
# Processing Record 39 of Set 9 | ulkan
# Processing Record 40 of Set 9 | kiruna
# Processing Record 41 of Set 9 | dori
# Processing Record 42 of Set 9 | uarini
# Processing Record 43 of Set 9 | pangkalanbuun
# Processing Record 44 of Set 9 | ouadda
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | cartagena del chaira
# Processing Record 47 of Set 9 | urusha
# Processing Record 48 of Set 9 | shitanjing
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | vila velha
# Processing Record 1 of Set 10 | nytva
# Processing Record 2 of Set 10 | rimbey
# Processing Record 3 of Set 10 | honningsvag
# Processing Record 4 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 10 | rodbyhavn
# Processing Record 6 of Set 10 | young
# Processing Record 7 of Set 10 | athboy
# Processing Record 8 of Set 10 | ribeira brava
# Processing Record 9 of Set 10 | aragarcas
# Processing Record 10 of Set 10 | hede
# Processing Record 11 of Set 10 | kirkuk
# Processing Record 12 of Set 10 | port blair
# Processing Record 13 of Set 10 | kharitonovo
# Processing Record 14 of Set 10 | palasa
# Processing Record 15 of Set 10 | bogovarovo
# Processing Record 16 of Set 10 | bac lieu
# Processing Record 17 of Set 10 | garm
# City not found. Skipping...
# Processing Record 18 of Set 10 | polyarnyy
# Processing Record 19 of Set 10 | omsukchan
# Processing Record 20 of Set 10 | katherine
# Processing Record 21 of Set 10 | salalah
# Processing Record 22 of Set 10 | pyapon
# Processing Record 23 of Set 10 | brae
# Processing Record 24 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 25 of Set 10 | banda aceh
# Processing Record 26 of Set 10 | kamaishi
# Processing Record 27 of Set 10 | sao felix do xingu
# Processing Record 28 of Set 10 | codrington
# Processing Record 29 of Set 10 | jalu
# Processing Record 30 of Set 10 | ambatondrazaka
# Processing Record 31 of Set 10 | siraha
# Processing Record 32 of Set 10 | inta
# Processing Record 33 of Set 10 | vila do maio
# Processing Record 34 of Set 10 | dolores
# Processing Record 35 of Set 10 | sligo
# Processing Record 36 of Set 10 | neryungri
# Processing Record 37 of Set 10 | limbang
# Processing Record 38 of Set 10 | hambantota
# Processing Record 39 of Set 10 | bontang
# Processing Record 40 of Set 10 | lokachi
# Processing Record 41 of Set 10 | crawfordsville
# Processing Record 42 of Set 10 | luderitz
# Processing Record 43 of Set 10 | carlyle
# Processing Record 44 of Set 10 | san quintin
# Processing Record 45 of Set 10 | livadia
# Processing Record 46 of Set 10 | warrnambool
# Processing Record 47 of Set 10 | nador
# Processing Record 48 of Set 10 | nanakuli
# Processing Record 49 of Set 10 | leningradskiy
# Processing Record 50 of Set 10 | latung
# Processing Record 1 of Set 11 | flinders
# Processing Record 2 of Set 11 | kysyl-syr
# Processing Record 3 of Set 11 | kutum
# Processing Record 4 of Set 11 | marquette
# Processing Record 5 of Set 11 | ahipara
# Processing Record 6 of Set 11 | salinopolis
# Processing Record 7 of Set 11 | tevriz
# Processing Record 8 of Set 11 | delcevo
# Processing Record 9 of Set 11 | balabac
# Processing Record 10 of Set 11 | viedma
# Processing Record 11 of Set 11 | sampit
# Processing Record 12 of Set 11 | punta cardon
# Processing Record 13 of Set 11 | talaya
# Processing Record 14 of Set 11 | big rapids
# Processing Record 15 of Set 11 | popondetta
# Processing Record 16 of Set 11 | severnyy
# Processing Record 17 of Set 11 | phalaborwa
# Processing Record 18 of Set 11 | katangli
# Processing Record 19 of Set 11 | inongo
# Processing Record 20 of Set 11 | nyazepetrovsk
# Processing Record 21 of Set 11 | birao
# Processing Record 22 of Set 11 | khorinsk
# Processing Record 23 of Set 11 | merauke
# Processing Record 24 of Set 11 | la ronge
# Processing Record 25 of Set 11 | sao joao da barra
# Processing Record 26 of Set 11 | yelan
# Processing Record 27 of Set 11 | zambezi
# Processing Record 28 of Set 11 | sheridan
# Processing Record 29 of Set 11 | black river
# Processing Record 30 of Set 11 | hasaki
# Processing Record 31 of Set 11 | tynda
# Processing Record 32 of Set 11 | myingyan
# Processing Record 33 of Set 11 | sarakhs
# Processing Record 34 of Set 11 | touros
# Processing Record 35 of Set 11 | berbera
# Processing Record 36 of Set 11 | joshimath
# Processing Record 37 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 11 | sur
# Processing Record 39 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 11 | alta floresta
# Processing Record 41 of Set 11 | kilindoni
# Processing Record 42 of Set 11 | matadi
# Processing Record 43 of Set 11 | hamilton
# Processing Record 44 of Set 11 | kerema
# Processing Record 45 of Set 11 | garowe
# Processing Record 46 of Set 11 | saint-georges
# Processing Record 47 of Set 11 | ryotsu
# Processing Record 48 of Set 11 | pilane
# Processing Record 49 of Set 11 | lata
# Processing Record 50 of Set 11 | constitucion
# Processing Record 1 of Set 12 | nago
# Processing Record 2 of Set 12 | da lat
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | chimbote
# Processing Record 5 of Set 12 | salta
# Processing Record 6 of Set 12 | paamiut
# Processing Record 7 of Set 12 | sistranda
# Processing Record 8 of Set 12 | terrasini
# Processing Record 9 of Set 12 | sambava
# Processing Record 10 of Set 12 | bibiani
# Processing Record 11 of Set 12 | bara
# Processing Record 12 of Set 12 | yelizovo
# Processing Record 13 of Set 12 | balsa
# Processing Record 14 of Set 12 | shelby
# Processing Record 15 of Set 12 | mingyue
# Processing Record 16 of Set 12 | calderitas
# Processing Record 17 of Set 12 | jackson
# Processing Record 18 of Set 12 | talcahuano
# Processing Record 19 of Set 12 | oranjestad
# Processing Record 20 of Set 12 | sanmenxia
# Processing Record 21 of Set 12 | akdepe
# Processing Record 22 of Set 12 | athens
# Processing Record 23 of Set 12 | porto novo
# Processing Record 24 of Set 12 | paveh
# Processing Record 25 of Set 12 | derzhavinsk
# Processing Record 26 of Set 12 | rehoboth
# Processing Record 27 of Set 12 | bauchi
# Processing Record 28 of Set 12 | cookshire
# City not found. Skipping...
# Processing Record 29 of Set 12 | huarmey
# Processing Record 30 of Set 12 | oeiras do para
# Processing Record 31 of Set 12 | bennington
# Processing Record 32 of Set 12 | maningrida
# Processing Record 33 of Set 12 | san patricio
# Processing Record 34 of Set 12 | chanika
# Processing Record 35 of Set 12 | nara
# Processing Record 36 of Set 12 | osakarovka
# Processing Record 37 of Set 12 | raton
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | vallenar
# Processing Record 40 of Set 12 | vanavara
# Processing Record 41 of Set 12 | muli
# Processing Record 42 of Set 12 | bollnas
# Processing Record 43 of Set 12 | pontianak
# Processing Record 44 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 12 | sisimiut
# Processing Record 46 of Set 12 | adrar
# Processing Record 47 of Set 12 | oceanside
# Processing Record 48 of Set 12 | namatanai
# Processing Record 49 of Set 12 | mackay
# Processing Record 50 of Set 12 | nichinan
# Processing Record 1 of Set 13 | negara
# Processing Record 2 of Set 13 | ketchikan
# Processing Record 3 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 13 | san antonio
# Processing Record 5 of Set 13 | kupino
# Processing Record 6 of Set 13 | nikolsk
# Processing Record 7 of Set 13 | ende
# Processing Record 8 of Set 13 | lieksa
# Processing Record 9 of Set 13 | mabaruma
# Processing Record 10 of Set 13 | atar
# Processing Record 11 of Set 13 | college
# Processing Record 12 of Set 13 | westport
# Processing Record 13 of Set 13 | san pedro
# Processing Record 14 of Set 13 | boyolangu
# Processing Record 15 of Set 13 | kurumkan
# Processing Record 16 of Set 13 | havre-saint-pierre
# Processing Record 17 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 13 | cabra
# Processing Record 19 of Set 13 | berlevag
# Processing Record 20 of Set 13 | noumea
# Processing Record 21 of Set 13 | corrales
# Processing Record 22 of Set 13 | mehamn
# Processing Record 23 of Set 13 | labuhan
# Processing Record 24 of Set 13 | mogadishu
# Processing Record 25 of Set 13 | road town
# Processing Record 26 of Set 13 | dabat
# Processing Record 27 of Set 13 | hami
# Processing Record 28 of Set 13 | huilong
# Processing Record 29 of Set 13 | darhan
# Processing Record 30 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 13 | dingle
# Processing Record 32 of Set 13 | chumikan
# Processing Record 33 of Set 13 | urumqi
# Processing Record 34 of Set 13 | umm bab
# Processing Record 35 of Set 13 | yar-sale
# Processing Record 36 of Set 13 | madhupur
# Processing Record 37 of Set 13 | natal
# Processing Record 38 of Set 13 | micheweni
# Processing Record 39 of Set 13 | oksfjord
# Processing Record 40 of Set 13 | yakeshi
# Processing Record 41 of Set 13 | axim
# Processing Record 42 of Set 13 | ambilobe
# Processing Record 43 of Set 13 | tonantins
# Processing Record 44 of Set 13 | lhokseumawe
# Processing Record 45 of Set 13 | cayenne
# Processing Record 46 of Set 13 | samoylovka
# Processing Record 47 of Set 13 | torbay
# Processing Record 48 of Set 13 | port macquarie
# Processing Record 49 of Set 13 | mitzic
# Processing Record 50 of Set 13 | kieta
# Processing Record 1 of Set 14 | tazovskiy
# Processing Record 2 of Set 14 | guntur
# Processing Record 3 of Set 14 | delmas
# Processing Record 4 of Set 14 | krasnogorsk
# Processing Record 5 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 14 | kushima
# Processing Record 7 of Set 14 | kemijarvi
# Processing Record 8 of Set 14 | saskylakh
# Processing Record 9 of Set 14 | seymchan
# Processing Record 10 of Set 14 | chokwe
# Processing Record 11 of Set 14 | digby
# Processing Record 12 of Set 14 | half moon bay
# Processing Record 13 of Set 14 | chernukha
# Processing Record 14 of Set 14 | itarema
# Processing Record 15 of Set 14 | basco
# Processing Record 16 of Set 14 | samarai
# Processing Record 17 of Set 14 | kenai
# Processing Record 18 of Set 14 | nizhniy ingash
# Processing Record 19 of Set 14 | piacabucu
# Processing Record 20 of Set 14 | simbahan
# Processing Record 21 of Set 14 | acapulco
# Processing Record 22 of Set 14 | yatou
# Processing Record 23 of Set 14 | florida
# Processing Record 24 of Set 14 | inirida
# Processing Record 25 of Set 14 | svobodnyy
# Processing Record 26 of Set 14 | birin
# Processing Record 27 of Set 14 | buchanan
# Processing Record 28 of Set 14 | wewak
# Processing Record 29 of Set 14 | kodumudi
# Processing Record 30 of Set 14 | rodino
# Processing Record 31 of Set 14 | chapais
# Processing Record 32 of Set 14 | locri
# Processing Record 33 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 14 | barra
# Processing Record 35 of Set 14 | cacoal
# Processing Record 36 of Set 14 | hirara
# Processing Record 37 of Set 14 | vargem grande do sul
# Processing Record 38 of Set 14 | ust-kuyga
# Processing Record 39 of Set 14 | walvis bay
# Processing Record 40 of Set 14 | anchorage
# Processing Record 41 of Set 14 | iracoubo
# Processing Record 42 of Set 14 | pavlysh
# Processing Record 43 of Set 14 | neiafu
# Processing Record 44 of Set 14 | miri
# Processing Record 45 of Set 14 | thai binh
# Processing Record 46 of Set 14 | ambagarh chauki
# Processing Record 47 of Set 14 | ndola
# Processing Record 48 of Set 14 | zlobin
# Processing Record 49 of Set 14 | camopi
# Processing Record 50 of Set 14 | saint-joseph
# Processing Record 1 of Set 15 | fairview
# Processing Record 2 of Set 15 | curitibanos
# Processing Record 3 of Set 15 | dickinson
# Processing Record 4 of Set 15 | belaya gora
# Processing Record 5 of Set 15 | ati
# Processing Record 6 of Set 15 | vilkaviskis
# Processing Record 7 of Set 15 | champerico
# Processing Record 8 of Set 15 | chulman
# Processing Record 9 of Set 15 | viamao
# Processing Record 10 of Set 15 | olafsvik
# Processing Record 11 of Set 15 | kalamb
# Processing Record 12 of Set 15 | surt
# Processing Record 13 of Set 15 | mitsamiouli
# Processing Record 14 of Set 15 | kadugannawa
# Processing Record 15 of Set 15 | vila franca do campo
# Processing Record 16 of Set 15 | olean
# Processing Record 17 of Set 15 | dinghai
# Processing Record 18 of Set 15 | port hardy
# Processing Record 19 of Set 15 | shimanovsk
# Processing Record 20 of Set 15 | simav
# Processing Record 21 of Set 15 | quang ngai
# Processing Record 22 of Set 15 | caborca
# Processing Record 23 of Set 15 | guatire
# Processing Record 24 of Set 15 | iskateley
# Processing Record 25 of Set 15 | pundaguitan
# Processing Record 26 of Set 15 | poya
# Processing Record 27 of Set 15 | cascais
# Processing Record 28 of Set 15 | taltal
# Processing Record 29 of Set 15 | kaputa
# Processing Record 30 of Set 15 | ukiah
# Processing Record 31 of Set 15 | deori khas
# Processing Record 32 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 15 | nurota
# Processing Record 34 of Set 15 | seoul
# Processing Record 35 of Set 15 | tangzhai
# Processing Record 36 of Set 15 | vidim
# Processing Record 37 of Set 15 | venice
# Processing Record 38 of Set 15 | jacareacanga
# Processing Record 39 of Set 15 | xingyi
# Processing Record 40 of Set 15 | atkarsk
# Processing Record 41 of Set 15 | pekan
# Processing Record 42 of Set 15 | limoges
# Processing Record 43 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 15 | nuevo progreso
# Processing Record 45 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 15 | caravelas
# Processing Record 47 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 48 of Set 15 | terekli-mekteb
# Processing Record 49 of Set 15 | kango
# Processing Record 50 of Set 15 | beloha
# Processing Record 1 of Set 16 | longyearbyen
# Processing Record 2 of Set 16 | quime
# Processing Record 3 of Set 16 | kavarna
# Processing Record 4 of Set 16 | antalaha
# Processing Record 5 of Set 16 | saint-leu
# Processing Record 6 of Set 16 | mount isa
# Processing Record 7 of Set 16 | erzin
# Processing Record 8 of Set 16 | barpeta
# Processing Record 9 of Set 16 | aryanah
# Processing Record 10 of Set 16 | malka
# Processing Record 11 of Set 16 | boa vista
# Processing Record 12 of Set 16 | lincoln
# Processing Record 13 of Set 16 | rakhya
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 713

# %%
city_data_df = pd.DataFrame(city_data)
# Create the output file (CSV)
output_data_file = "Weather_Databse/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-aa8f4d01c9c8> in <module>
# ----> 1 city_data_df = pd.DataFrame(city_data)
#       2 # Create the output file (CSV)
#       3 output_data_file = "WeatherPy_Database.csv"
#       4 # Export the City_Data into a CSV
#       5 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# NameError: name 'city_data' is not defined

# %%
city_data_to_load = "WeatherPy_Database.csv"
city_data = pd.read_csv(city_data_to_load)
